# %%
# Dependencies and Setup
import pandas as pd

# %%
# Bring in CSVs
data_2019 = pd.read_csv("201910-citibike-tripdata.csv")
data_2020 = pd.read_csv("202010-citibike-tripdata.csv")

# %%
# data_2013_clean = data_2013.dropna()
data_2019["gender"] = data_2019["gender"].replace([0, 1, 2],["Unknown", "Male", "Female"])
data_2019
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1                 174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2                 759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3                 615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4                 761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
# ...               ...                       ...                       ...
# 2092568           729  2019-10-31 23:59:12.1900  2019-11-01 00:11:21.4860
# 2092569           645  2019-10-31 23:59:17.0470  2019-11-01 00:10:02.9450
# 2092570           257  2019-10-31 23:59:22.5140  2019-11-01 00:03:40.2600
# 2092571           466  2019-10-31 23:59:23.1710  2019-11-01 00:07:09.2050
# 2092572            81  2019-10-31 23:59:51.5170  2019-11-01 00:01:13.2150
#
#          start station id              start station name  \
# ...

# %%
# data_2014_clean = data_2014.dropna()
data_2020["gender"] = data_2020["gender"].replace([0, 1, 2],["Unknown", "Male", "Female"])
data_2020
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1403  2020-10-01 00:00:10.7870  2020-10-01 00:23:34.5400
# 1                 462  2020-10-01 00:00:18.2390  2020-10-01 00:08:00.5710
# 2                 770  2020-10-01 00:00:21.3070  2020-10-01 00:13:12.0840
# 3                 233  2020-10-01 00:00:25.0080  2020-10-01 00:04:18.6410
# 4                 126  2020-10-01 00:00:25.3100  2020-10-01 00:02:32.1330
# ...               ...                       ...                       ...
# 2248864          1120  2020-10-31 23:59:48.4470  2020-11-01 00:18:29.3280
# 2248865           859  2020-10-31 23:59:49.3770  2020-11-01 00:14:09.1920
# 2248866           546  2020-10-31 23:59:52.1040  2020-11-01 00:08:59.0710
# 2248867           748  2020-10-31 23:59:53.0290  2020-11-01 00:12:21.7830
# 2248868          1366  2020-10-31 23:59:57.9770  2020-11-01 00:22:44.1290
#
#          start station id                  start station name  \
# ...

# %%
data_2019.to_csv("data_2019.csv", encoding="utf-8", index=False)
data_2020.to_csv("data_2020.csv", encoding="utf-8", index=False)
